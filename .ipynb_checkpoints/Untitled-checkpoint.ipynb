# %%
from Bio.motifs import meme
with open("for_fimo/Saccharomyces_cerevisiae_CISBP2.meme" ,'r') as f:
     record = f.readlines()

# %%
mots = {i.split(' ')[2].strip():i.split(' ')[1] for i in record if 'MOTIF' in i}

# %%
mots
# Out:
# {'ABF1': 'M00001_2.00',
#  'AFT2': 'M00002_2.00',
#  'MBP1': 'M00003_2.00',
#  'SWI4': 'M00004_2.00',
#  'XBP1': 'M00005_2.00',
#  'PHD1': 'M00006_2.00',
#  'SOK2': 'M00007_2.00',
#  'SUM1': 'M00008_2.00',
#  'PHO4': 'M00009_2.00',
#  'CBF1': 'M00010_2.00',
#  'TYE7': 'M00011_2.00',
#  'HAC1': 'M00012_2.00',
#  'YAP3': 'M00013_2.00',
#  'CST6': 'M00014_2.00',
#  'CIN5': 'M00015_2.00',
#  'REI1': 'M00016_2.00',
#  'RPN4': 'M00017_2.00',
#  'STP4': 'M00018_2.00',
#  'GIS1': 'M00019_2.00',
#  'SWI5': 'M00020_2.00',
#  'ADR1': 'M00021_2.00',
#  'MET32': 'M00022_2.00',
#  'MIG3': 'M00023_2.00',
#  'COM2': 'M00024_2.00',
#  'RPH1': 'M00025_2.00',
#  'MIG1': 'M00026_2.00',
#  'MIG2': 'M00027_2.00',
#  'FZF1': 'M00028_2.00',
#  'YGR067C': 'M00029_2.00',
#  'RIM101': 'M00030_2.00',
#  'RSF2': 'M00031_2.00',
#  'MSN4': 'M00032_2.00',
#  'ACE2': 'M00033_2.00',
#  'STP3': 'M00034_2.00',
#  'TDA9': 'M00035_2.00',
#  'MSN2': 'M00036_2.00',
#  'RGM1': 'M00037_2.00',
#  'CRZ1': 'M00038_2.00',
# ...

# %%
all_tfs = ['Vhr2',
 'Nrg2',
 'Pdr8',
 'Abf1',
 'Crz1',
 'Gln3',
 'Reb1',
 'Met31',
 'Rpn4',
 'Sko1',
 'Cst6']

# %%
for tf in all_tfs:
    print(tf, mots[tf.upper()])
    continue
# Out:
# Vhr2 M00917_2.00
# Nrg2 M00909_2.00
# Pdr8 M00098_2.00
# Abf1 M00001_2.00
# Crz1 M00038_2.00
# Gln3 M00048_2.00
# Reb1 M00063_2.00
# Met31 M00040_2.00
# Rpn4 M00017_2.00
# Sko1 M00907_2.00
# Cst6 M00014_2.00

# %%
import os

# %%
for tf in all_tfs:
    os.system('./find_mots.sh {}'.format(mots[tf.upper()], tf))
# Out:
# Give me a tf name
# Give me a tf name
# Give me a tf name
# Give me a tf name
# Give me a tf name
# Give me a tf name
# Give me a tf name
# Give me a tf name
# Give me a tf name
# Give me a tf name
# Give me a tf name
# ./find_mots.sh: line 5: module: command not found
# ./find_mots.sh: line 6: fimo: command not found
# ./find_mots.sh: line 5: module: command not found
# ./find_mots.sh: line 6: fimo: command not found
# ./find_mots.sh: line 5: module: command not found
# ./find_mots.sh: line 6: fimo: command not found
# ./find_mots.sh: line 5: module: command not found
# ./find_mots.sh: line 6: fimo: command not found
# ./find_mots.sh: line 5: module: command not found
# ./find_mots.sh: line 6: fimo: command not found
# ./find_mots.sh: line 5: module: command not found
# ./find_mots.sh: line 6: fimo: command not found
# ./find_mots.sh: line 5: module: command not found
# ./find_mots.sh: line 6: fimo: command not found
# ./find_mots.sh: line 5: module: command not found
# ...
